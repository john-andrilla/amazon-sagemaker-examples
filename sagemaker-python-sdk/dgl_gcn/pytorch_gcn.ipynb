# %% [markdown]
# ## Training SageMaker Models using the DGL with Pytorch backend
# The **SageMaker Python SDK** makes it easy to train DGL models. In this example, we train a simple graph neural network using the [DMLC DGL API](https://github.com/dmlc/dgl.git) and the [Cora dataset](https://relational.fit.cvut.cz/dataset/CORA). The Cora dataset describes a citation network. The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. The task at hand is to train a node classification model using Cora dataset.

# %% [markdown]
# ### Setup
# We need to define a few variables that will be needed later in the example.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.session import Session

# Setup session
sess = sagemaker.Session()

# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket here if you wish.
bucket = sess.default_bucket()

# Location to put your custom code.
custom_code_upload_location = 'customcode'

# IAM execution role that gives SageMaker access to resources in your AWS account.
# We can use the SageMaker Python SDK to get the role from our notebook environment. 
role = get_execution_role()

# %% [markdown]
# ### The training script
# The pytorch_gcn.py script provides all the code we need for training a SageMaker model.

# %%
# !cat pytorch_gcn.py
# Out:
# import torch
# import torch.nn as nn
# from dgl.nn.pytorch import GraphConv
#
# import os
# import time
# import json
# import argparse
# import numpy as np
# import torch.nn.functional as F
# from dgl import DGLGraph
# from dgl.data import register_data_args, load_data
#
# # define GCN layer
# class GCN(nn.Module):
#     def __init__(self,
#                  g,
#                  in_feats,
#                  n_hidden,
#                  n_classes,
#                  n_layers,
#                  activation,
#                  dropout):
#         super(GCN, self).__init__()
#         self.g = g
#         self.layers = nn.ModuleList()
#         # input layer
#         self.layers.append(GraphConv(in_feats, n_hidden, activation=activation))
#         # hidden layers
#         for i in range(n_layers - 1):
#             self.layers.append(GraphConv(n_hidden, n_hidden, activation=activation))
#         # output layer
#         self.layers.append(GraphConv(n_hidden, n_classes))
#         self.dropout = nn.Dropout(p=dropout)
#
#     def forward(self, features):
#         h = features
#         for i, layer in enumerate(self.layers):
#             if i != 0:
#                 h = self.dropout(h)
#             h = layer(self.g, h)
#         return h
#
# def evaluate(model, features, labels, mask):
#     model.eval()
#     with torch.no_grad():
#         logits = model(features)
#         logits = logits[mask]
#         labels = labels[mask]
#         _, indices = torch.max(logits, dim=1)
#         correct = torch.sum(indices == labels)
#         return correct.item() * 1.0 / len(labels)
#
# def main(args):
#     # load and preprocess dataset
#     data = load_data(args)
#     features = torch.FloatTensor(data.features)
#     labels = torch.LongTensor(data.labels)
#     train_mask = torch.ByteTensor(data.train_mask)
#     val_mask = torch.ByteTensor(data.val_mask)
#     test_mask = torch.ByteTensor(data.test_mask)
#     in_feats = features.shape[1]
#     n_classes = data.num_labels
#     n_edges = data.graph.number_of_edges()
#     print("""----Data statistics------'
#       #Edges %d
#       #Classes %d
#       #Train samples %d
#       #Val samples %d
#       #Test samples %d""" %
#           (n_edges, n_classes,
#               train_mask.sum().item(),
#               val_mask.sum().item(),
#               test_mask.sum().item()))
#
#     if args.gpu < 0:
#         cuda = False
#     else:
#         cuda = True
#         torch.cuda.set_device(args.gpu)
#         features = features.cuda()
#         labels = labels.cuda()
#         train_mask = train_mask.cuda()
#         val_mask = val_mask.cuda()
#         test_mask = test_mask.cuda()
#
#     # graph preprocess and calculate normalization factor
#     g = data.graph
#     # add self loop
#     if args.self_loop:
#         g.remove_edges_from(g.selfloop_edges())
#         g.add_edges_from(zip(g.nodes(), g.nodes()))
#     g = DGLGraph(g)
#     n_edges = g.number_of_edges()
#     # normalization
#     degs = g.in_degrees().float()
#     norm = torch.pow(degs, -0.5)
#     norm[torch.isinf(norm)] = 0
#     if cuda:
#         norm = norm.cuda()
#     g.ndata['norm'] = norm.unsqueeze(1)
#
#     # create GCN model
#     model = GCN(g,
#                 in_feats,
#                 args.n_hidden,
#                 n_classes,
#                 args.n_layers,
#                 F.relu,
#                 args.dropout)
#
#     if cuda:
#         model.cuda()
#     loss_fcn = torch.nn.CrossEntropyLoss()
#
#     # use optimizer
#     optimizer = torch.optim.Adam(model.parameters(),
#                                  lr=args.lr,
#                                  weight_decay=args.weight_decay)
#
#     # initialize graph
#     dur = []
#     for epoch in range(args.n_epochs):
#         model.train()
#         if epoch >= 3:
#             t0 = time.time()
#         # forward
#         logits = model(features)
#         loss = loss_fcn(logits[train_mask], labels[train_mask])
#
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#
#         if epoch >= 3:
#             dur.append(time.time() - t0)
#
#         acc = evaluate(model, features, labels, val_mask)
#         print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | Accuracy {:.4f} | "
#               "ETputs(KTEPS) {:.2f}". format(epoch, np.mean(dur), loss.item(),
#                                              acc, n_edges / np.mean(dur) / 1000))
#
#     print()
#     acc = evaluate(model, features, labels, test_mask)
#     print("Test Accuracy {:.2%}".format(acc))
#
#     torch.save(model.state_dict(), args.save_path)
#
# import collections
# import warnings
# warnings.filterwarnings("ignore")
#
# def parse_args():
#     parser = argparse.ArgumentParser(description='GCN')
#     register_data_args(parser)
#     parser.add_argument("--dropout", type=float, default=0.5,
#             help="dropout probability")
#     parser.add_argument("--gpu", type=int, default=-1,
#             help="gpu")
#     parser.add_argument("--lr", type=float, default=3e-2,
#             help="learning rate")
#     parser.add_argument("--n-epochs", type=int, default=200,
#             help="number of training epochs")
#     parser.add_argument("--n-hidden", type=int, default=16,
#             help="number of hidden gcn units")
#     parser.add_argument("--n-layers", type=int, default=1,
#             help="number of hidden gcn layers")
#     parser.add_argument("--weight-decay", type=float, default=5e-4,
#             help="Weight for L2 loss")
#     parser.add_argument("--self-loop", action='store_true',
#             help="graph self-loop (default=False)")
#     parser.add_argument("--save-path", type=str, default='./model/gcn.pt',
#             help="path to save model")
#     parser.set_defaults(self_loop=False)
#
#     return parser.parse_args()
#
# if __name__ == '__main__':
#     args = parse_args()
#
#     num_gpus = int(os.environ['SM_NUM_GPUS'])
#     if num_gpus == 0:
#         args.gpu = -1
#     else:
#         args.gpu = 0
#
#     path = str(os.environ['SM_MODEL_DIR'])
#     args.save_path = os.path.join(path, 'gcn.pt')
#
#     print(args)
#     main(args)

# %% [markdown]
# ### SageMaker's  estimator class
# The SageMaker Estimator allows us to run single machine in SageMaker, using CPU or GPU-based instances.
#
# When we create the estimator, we pass in the filename of our training script, the name of our IAM execution role. We also provide a few other parameters. train_instance_count and train_instance_type determine the number and type of SageMaker instances that will be used for the training job. The hyperparameters parameter is a dict of values that will be passed to your training script -- you can see how to access these values in the pytorch_gcn.py script above.
#
# Here we can use the official docker image for this example, please see https://github.com/aws/sagemaker-pytorch-container for more information.

# %%
from sagemaker.pytorch import PyTorch

CODE_PATH = 'pytorch_gcn.py'
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name

docker_name = 'beta-pytorch-training'
docker_tag = '1.3.0-py3-cpu-build'
image = '{}.dkr.ecr.{}.amazonaws.com/{}:{}'.format(account, region, docker_name, docker_tag)
print(image)

params = {}
params['dataset'] = 'cora'
estimator = PyTorch(entry_point=CODE_PATH,
                        role=role, 
                        train_instance_count=1, 
                        train_instance_type='ml.c4.xlarge',
                        image_name=image,
                        hyperparameters=params,
                        sagemaker_session=sess)
# Out:
# No framework_version specified, defaulting to version 0.4.
# 397262719838.dkr.ecr.us-east-2.amazonaws.com/beta-pytorch-training:1.3.0-py3-cpu-build

# %% [markdown]
# ### Running the Training Job
# After we've constructed our Estimator object, we can fit it using sagemaker (The dataset will be automatically downloaded). Below we run SageMaker training on one channels: training-code, the code to run.

# %%
estimator.fit()
# Out:
# 2019-11-24 14:06:21 Starting - Starting the training job...
# 2019-11-24 14:06:22 Starting - Launching requested ML instances...
# 2019-11-24 14:07:16 Starting - Preparing the instances for training......
# 2019-11-24 14:08:06 Downloading - Downloading input data
# 2019-11-24 14:08:06 Training - Downloading the training image.........
# 2019-11-24 14:09:42 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2019-11-24 14:09:43,350 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2019-11-24 14:09:43,353 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-11-24 14:09:43,364 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2019-11-24 14:09:46,382 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2019-11-24 14:09:46,716 sagemaker-containers INFO     Module pytorch_gcn does not provide a setup.py.
# Generating setup.py
# 2019-11-24 14:09:46,716 sagemaker-containers INFO     Generating setup.cfg
# 2019-11-24 14:09:46,717 sagemaker-containers INFO     Generating MANIFEST.in
# 2019-11-24 14:09:46,717 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: pytorch-gcn
#   Building wheel for pytorch-gcn (setup.py): started
#   Building wheel for pytorch-gcn (setup.py): finished with status 'done'
#   Created wheel for pytorch-gcn: filename=pytorch_gcn-1.0.0-py2.py3-none-any.whl size=8118 sha256=89fc01f058f9b08b854c7cab7ce113ec471d0f7823dfdc1846442564795d1d52
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7rer34r_/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built pytorch-gcn
# Installing collected packages: pytorch-gcn
# Successfully installed pytorch-gcn-1.0.0
# 2019-11-24 14:09:48,982 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-11-24 14:09:48,994 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "dataset": "cora"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "beta-pytorch-training-2019-11-24-14-06-21-092",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-397262719838/beta-pytorch-training-2019-11-24-14-06-21-092/source/sourcedir.tar.gz",
#     "module_name": "pytorch_gcn",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_gcn.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset":"cora"}
# SM_USER_ENTRY_POINT=pytorch_gcn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_gcn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-397262719838/beta-pytorch-training-2019-11-24-14-06-21-092/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"dataset":"cora"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"beta-pytorch-training-2019-11-24-14-06-21-092","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-397262719838/beta-pytorch-training-2019-11-24-14-06-21-092/source/sourcedir.tar.gz","module_name":"pytorch_gcn","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"pytorch_gcn.py"}
# SM_USER_ARGS=["--dataset","cora"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_DATASET=cora
# PYTHONPATH=/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python -m pytorch_gcn --dataset cora
#
#
# Namespace(dataset='cora', dropout=0.5, gpu=-1, lr=0.03, n_epochs=200, n_hidden=16, n_layers=1, save_path='/opt/ml/model/gcn.pt', self_loop=False, syn_gnp_n=1000, syn_gnp_p=0.0, syn_nclasses=10, syn_nfeats=500, syn_seed=42, syn_test_ratio=0.5, syn_train_ratio=0.1, syn_type='gnp', syn_val_ratio=0.2, weight_decay=0.0005)
# Downloading /root/.dgl/cora.zip from https://s3.us-east-2.amazonaws.com/dgl.ai/dataset/cora_raw.zip...
# Extracting file to /root/.dgl/cora
# ----Data statistics------'
#       #Edges 10556
#       #Classes 7
#       #Train samples 140
#       #Val samples 300
#       #Test samples 1000
# [2019-11-24 14:09:56.144 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.144 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.145 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.145 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.177 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.178 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.187 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.187 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.202 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.202 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.202 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.203 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.206 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.206 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.256 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.256 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.257 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.257 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.267 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.267 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.268 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.268 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00000 | Time(s) nan | Loss 1.9453 | Accuracy 0.3933 | ETputs(KTEPS) nan
# [2019-11-24 14:09:56.274 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.274 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.275 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.275 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.284 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.285 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.287 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.288 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.296 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.296 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.296 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.297 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.297 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.298 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.313 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.313 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.314 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.314 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.323 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.324 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.324 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.325 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00001 | Time(s) nan | Loss 1.9117 | Accuracy 0.3267 | ETputs(KTEPS) nan
# [2019-11-24 14:09:56.331 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.331 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.331 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.332 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.341 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.341 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.344 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.344 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.347 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.347 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.348 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.348 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.349 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.349 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.359 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.359 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.360 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.360 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.370 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.370 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.370 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.371 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00002 | Time(s) nan | Loss 1.8653 | Accuracy 0.3200 | ETputs(KTEPS) nan
# [2019-11-24 14:09:56.377 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.378 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.378 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.378 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.393 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.393 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.404 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.404 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.419 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.420 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.420 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.420 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.421 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.421 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.456 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.457 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.457 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.457 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.467 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.467 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.467 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.467 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00003 | Time(s) 0.0791 | Loss 1.8289 | Accuracy 0.3767 | ETputs(KTEPS) 133.52
# [2019-11-24 14:09:56.471 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.471 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.471 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.471 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.499 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.500 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.509 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.511 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.523 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.524 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.524 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.524 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.525 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.525 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.570 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.570 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.571 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.571 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.598 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.599 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.599 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.601 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00004 | Time(s) 0.0891 | Loss 1.7897 | Accuracy 0.4200 | ETputs(KTEPS) 118.48
# [2019-11-24 14:09:56.615 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.616 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.616 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.616 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.646 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.647 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.659 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.659 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.671 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.671 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.671 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.671 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.671 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.672 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.716 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.716 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.717 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.717 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.730 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.730 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.730 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.730 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00005 | Time(s) 0.0929 | Loss 1.7392 | Accuracy 0.4567 | ETputs(KTEPS) 113.65
# [2019-11-24 14:09:56.736 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.736 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.736 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.736 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.745 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.745 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.747 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.748 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.751 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.751 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.751 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.752 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.752 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.752 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.789 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.789 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.789 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.789 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.798 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.798 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.799 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.799 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00006 | Time(s) 0.0828 | Loss 1.7315 | Accuracy 0.4633 | ETputs(KTEPS) 127.50
# [2019-11-24 14:09:56.804 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.804 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.805 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.805 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.813 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.813 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.815 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.815 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.819 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.819 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.819 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.820 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.820 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.820 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.833 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.833 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.834 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.834 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.842 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.842 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.842 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.843 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00007 | Time(s) 0.0720 | Loss 1.6908 | Accuracy 0.4200 | ETputs(KTEPS) 146.67
# [2019-11-24 14:09:56.847 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.847 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.847 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.847 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.871 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.871 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.884 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.884 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.896 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.897 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.897 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.897 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.897 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.898 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.912 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.912 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.914 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.915 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.944 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.944 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.947 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.947 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00008 | Time(s) 0.0707 | Loss 1.7081 | Accuracy 0.4033 | ETputs(KTEPS) 149.29
# [2019-11-24 14:09:56.964 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.964 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.964 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.965 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:56.994 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:56.994 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.008 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.008 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.018 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.019 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.021 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.021 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.021 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.022 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.035 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.036 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.036 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.036 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.045 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.045 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.045 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.045 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00009 | Time(s) 0.0708 | Loss 1.6702 | Accuracy 0.4000 | ETputs(KTEPS) 149.10
# [2019-11-24 14:09:57.060 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.061 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.061 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.062 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.094 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.095 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.104 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.105 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.108 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.109 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.109 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.109 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.109 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.109 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.147 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.147 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.147 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.147 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.174 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.174 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.174 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.175 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00010 | Time(s) 0.0727 | Loss 1.6211 | Accuracy 0.4033 | ETputs(KTEPS) 145.17
# [2019-11-24 14:09:57.193 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.193 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.193 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.193 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.223 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.224 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.235 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.235 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.246 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.248 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.249 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.249 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.249 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.249 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.288 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.288 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.289 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.289 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.316 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.317 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.317 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.317 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00011 | Time(s) 0.0752 | Loss 1.6029 | Accuracy 0.4100 | ETputs(KTEPS) 140.32
# [2019-11-24 14:09:57.333 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.334 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.334 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.334 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.360 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.360 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.371 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.372 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.384 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.384 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.384 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.384 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.385 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.385 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.420 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.420 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.420 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.420 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.430 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.430 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.431 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.431 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00012 | Time(s) 0.0764 | Loss 1.5878 | Accuracy 0.4100 | ETputs(KTEPS) 138.19
# [2019-11-24 14:09:57.443 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.444 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.444 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.444 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.470 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.471 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.481 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.481 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.494 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.495 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.495 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.495 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.496 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:09:57.496 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:09:57.535 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# ...
# [2019-11-24 14:10:13.567 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.570 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.570 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.578 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.581 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.581 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.582 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.582 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.583 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.629 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.629 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.630 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.630 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.659 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.662 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.662 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.662 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00195 | Time(s) 0.0613 | Loss 0.3161 | Accuracy 0.8033 | ETputs(KTEPS) 172.13
# [2019-11-24 14:10:13.671 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.671 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.672 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.672 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.681 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.681 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.684 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.684 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.689 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.689 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.690 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.690 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.691 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.691 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.729 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.730 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.730 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.731 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.740 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.741 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.741 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.742 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00196 | Time(s) 0.0613 | Loss 0.3789 | Accuracy 0.8000 | ETputs(KTEPS) 172.17
# [2019-11-24 14:10:13.747 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.748 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.748 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.749 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.758 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.759 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.761 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.762 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.767 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.768 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.768 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.769 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.769 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.769 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.807 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.808 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.808 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.809 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.822 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.822 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.823 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.823 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00197 | Time(s) 0.0613 | Loss 0.4429 | Accuracy 0.8067 | ETputs(KTEPS) 172.19
# [2019-11-24 14:10:13.830 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.830 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.830 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.831 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.844 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.844 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.856 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.856 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.869 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.869 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.870 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.870 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.870 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.870 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.886 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.887 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.887 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.887 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.920 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.920 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.920 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.921 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00198 | Time(s) 0.0613 | Loss 0.4007 | Accuracy 0.8033 | ETputs(KTEPS) 172.26
# [2019-11-24 14:10:13.930 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.931 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.931 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.931 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.941 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.941 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.950 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.950 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.965 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.965 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.965 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.966 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.966 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.966 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.983 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.983 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:13.983 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:13.984 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:14.012 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.014 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:14.015 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.015 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Epoch 00199 | Time(s) 0.0612 | Loss 0.4010 | Accuracy 0.8033 | ETputs(KTEPS) 172.39
#
# [2019-11-24 14:10:14.032 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.032 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:14.033 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.033 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:14.053 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.054 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# [2019-11-24 14:10:14.054 algo-1:41 INFO json_config.py:86] Loaded Hook configuration from /opt/ml/input/config/debughookconfig.json
# [2019-11-24 14:10:14.054 algo-1:41 INFO singleton_utils.py:28] smdebug is disabled, since hook not created in code and no json config file.
# Test Accuracy 82.50%
# 2019-11-24 14:10:14,235 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-11-24 14:10:24 Completed - Training job completed
# Training seconds: 146
# Billable seconds: 146

# %% [markdown]
# ## Output
# You can get the model training output from the Sagemaker Console by searching for the training task named pytorch-gcn and looking for the address of 'S3 model artifact'
